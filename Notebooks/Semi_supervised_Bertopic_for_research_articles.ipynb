# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (0.14.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (2.2.2)
# Requirement already satisfied: numpy>=1.20.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (1.22.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (0.8.29)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (1.1.0)
# Requirement already satisfied: pandas>=1.1.5 in /databricks/python3/lib/python3.9/site-packages (from bertopic) (1.4.2)
# Requirement already satisfied: plotly>=4.7.0 in /databricks/python3/lib/python3.9/site-packages (from bertopic) (5.6.0)
# Requirement already satisfied: umap-learn>=0.5.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (0.5.3)
# Requirement already satisfied: tqdm>=4.41.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from bertopic) (4.65.0)
# Requirement already satisfied: cython>=0.27 in /databricks/python3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (0.29.28)
# Requirement already satisfied: joblib>=1.0 in /databricks/python3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (1.1.1)
# Requirement already satisfied: scipy>=1.0 in /databricks/python3/lib/python3.9/site-packages (from hdbscan>=0.8.29->bertopic) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.1.5->bertopic) (2021.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from plotly>=4.7.0->bertopic) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (2.2.0)
# Requirement already satisfied: torchvision in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: torch>=1.6.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: nltk in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.22.0)
# Requirement already satisfied: sentencepiece in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: pyyaml>=5.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /databricks/python3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.9.0)
# Requirement already satisfied: packaging>=20.9 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: requests in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.28.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.7.99)
# Requirement already satisfied: jinja2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (10.2.10.91)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.7.101)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.7.4.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.10.3.66)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.4.0.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.14.3)
# Requirement already satisfied: triton==2.0.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: sympy in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (11.7.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (10.9.0.58)
# Requirement already satisfied: networkx in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (8.5.0.96)
# Requirement already satisfied: wheel in /databricks/python3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (0.37.0)
# Requirement already satisfied: setuptools in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (67.6.1)
# Requirement already satisfied: lit in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.0)
# Requirement already satisfied: cmake in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.26.1)
# Requirement already satisfied: regex!=2019.12.17 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.3.23)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.12.1)
# Requirement already satisfied: pynndescent>=0.5 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.8)
# Requirement already satisfied: numba>=0.49 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.1)
# Requirement already satisfied: click in /databricks/python3/lib/python3.9/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: mpmath>=0.19 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /databricks/python3/lib/python3.9/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.0.1)
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-da9440ea-8bbf-49e7-a245-361f2e563c0a/bin/python -m pip install --upgrade pip' command.

# %%
import spacy

# %%
# !python -m spacy download en_core_web_lg

# %% [markdown]
# ## load data and perform minimal preprocessing since
# ### 1. we gonna use sentence transformer as base model for bertopicand
# ### 2. unlike a conversation, the language of this dataset is information dense, thus do not need much preprocessing to filter out noises

# %%
import pandas as pd
test_df=pd.read_csv("/dbfs/FileStore/articles_test.csv")
train_df=pd.read_csv("/dbfs/FileStore/articles_train.csv")

# %%
import re
def reflection_tokenizer(text):
    '''expects a string and returns a string with tokens that are lower cased and 
        non-alphanumeric characters as well as numbers removed.'''
    text=re.sub(r'[\W_]+', ' ', text) #keeps alphanumeric characters
    text=re.sub(r'\d+', '', text) #removes numbers
    text = text.lower()
    return text
train_df['preprocessed_abstract']=train_df['ABSTRACT'].apply(reflection_tokenizer)
test_df['preprocessed_abstract']=test_df['ABSTRACT'].apply(reflection_tokenizer)

# %%
import numpy as np
train_df["label"]=np.where(train_df["Computer Science"]==1,'Computer Science',np.where(train_df['Physics']==1,'Physics',np.where(train_df['Mathematics']==1,'Mathematics',np.where(train_df['Statistics']==1,'Statistics',np.where(train_df['Quantitative Biology']==1,'Quantitative Biology','Quantitative Finance')))))
train_df['label_num']=train_df['label'].map({'Computer Science': 0, 'Physics': 1,'Mathematics':2, 'Statistics':3, 'Quantitative Biology':4, 'Quantitative Finance':5})
train_df=train_df.drop(columns=['Computer Science','Physics','Mathematics','Statistics','Quantitative Biology','Quantitative Finance'])
train_df.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>TITLE</th>
#       <th>ABSTRACT</th>
#       <th>preprocessed_abstract</th>
#       <th>label</th>
#       <th>label_num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Reconstructing Subject-Specific Effect Maps</td>
#       <td>Predictive models allow subject-specific inf...</td>
#       <td>predictive models allow subject specific infe...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Rotation Invariance Neural Network</td>
#       <td>Rotation invariance and translation invarian...</td>
#       <td>rotation invariance and translation invarianc...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Spherical polyharmonics and Poisson kernels fo...</td>
#       <td>We introduce and develop the notion of spher...</td>
#       <td>we introduce and develop the notion of spheri...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>A finite element approximation for the stochas...</td>
#       <td>The stochastic Landau--Lifshitz--Gilbert (LL...</td>
#       <td>the stochastic landau lifshitz gilbert llg eq...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Comparative study of Discrete Wavelet Transfor...</td>
#       <td>Fourier-transform infra-red (FTIR) spectra o...</td>
#       <td>fourier transform infra red ftir spectra of s...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>On maximizing the fundamental frequency of the...</td>
#       <td>Let $\Omega \subset \mathbb{R}^n$ be a bound...</td>
#       <td>let omega subset mathbb r n be a bounded doma...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>On the rotation period and shape of the hyperb...</td>
#       <td>We observed the newly discovered hyperbolic ...</td>
#       <td>we observed the newly discovered hyperbolic m...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Adverse effects of polymer coating on heat tra...</td>
#       <td>The ability of metallic nanoparticles to sup...</td>
#       <td>the ability of metallic nanoparticles to supp...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>SPH calculations of Mars-scale collisions: the...</td>
#       <td>We model large-scale ($\approx$2000km) impac...</td>
#       <td>we model large scale approx km impacts on a m...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>$\mathcal{R}_{0}$ fails to predict the outbrea...</td>
#       <td>Time varying susceptibility of host at indiv...</td>
#       <td>time varying susceptibility of host at indivi...</td>
#       <td>Quantitative Biology</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>A global sensitivity analysis and reduced orde...</td>
#       <td>We present a systematic global sensitivity a...</td>
#       <td>we present a systematic global sensitivity an...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>Role-separating ordering in social dilemmas co...</td>
#       <td>"Three is a crowd" is an old proverb that ap...</td>
#       <td>three is a crowd is an old proverb that appli...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Dynamics of exciton magnetic polarons in CdMnS...</td>
#       <td>We study the exciton magnetic polaron (EMP) ...</td>
#       <td>we study the exciton magnetic polaron emp for...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>On Varieties of Ordered Automata</td>
#       <td>The classical Eilenberg correspondence, base...</td>
#       <td>the classical eilenberg correspondence based ...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>Direct Evidence of Spontaneous Abrikosov Vorte...</td>
#       <td>Using low-temperature Magnetic Force Microsc...</td>
#       <td>using low temperature magnetic force microsco...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>A rank 18 Waring decomposition of $sM_{\langle...</td>
#       <td>The recent discovery that the exponent of ma...</td>
#       <td>the recent discovery that the exponent of mat...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>The PdBI Arcsecond Whirlpool Survey (PAWS). Th...</td>
#       <td>The process that leads to the formation of t...</td>
#       <td>the process that leads to the formation of th...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>Higher structure in the unstable Adams spectra...</td>
#       <td>We describe a variant construction of the un...</td>
#       <td>we describe a variant construction of the uns...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>Comparing Covariate Prioritization via Matchin...</td>
#       <td>When investigators seek to estimate causal e...</td>
#       <td>when investigators seek to estimate causal ef...</td>
#       <td>Statistics</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>Acoustic Impedance Calculation via Numerical S...</td>
#       <td>Assigning homogeneous boundary conditions, s...</td>
#       <td>assigning homogeneous boundary conditions suc...</td>
#       <td>Physics</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Semi-supervised Topic Modeling:
# ### Using Semi-supervised Bertopic model to nudge the creation of topics toward certain pre-specified topics.
# ### Semi-supervised modeling allows us to steer the dimensionality reduction of the embeddings into a space that closely follows any labels we already have.

# %% [markdown]
# To perform this semi-supervised approach, we can take in some pre-defined topics and simply pass those to the y parameter when fitting BERTopic. These labels can be pre-defined topics or simply documents that you feel belong together regardless of their content. BERTopic will nudge the creation of topics toward these categories using the pre-defined labels.
#
# To perform supervised topic modeling, we simply use all categories:
#
# topic_model = BERTopic(verbose=True).fit(docs, y=categories)
# The topic model will be much more attuned to the categories that were defined previously.
# ### However, this does not mean that only topics for these categories will be found. BERTopic is likely to find more specific topics in those we have already defined. This allows us to discover previously unknown topics

# %%
print(train_df['ABSTRACT'].count())
print(test_df['ABSTRACT'].count())
# Out:
# 20972
# 8989

# %%
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.representation import PartOfSpeech
from bertopic.vectorizers import ClassTfidfTransformer

# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")#all-mpnet-base-v2

# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer(ngram_range=(1, 3))

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer()

# Step 6 - (Optional) Fine-tune topic representations with key bert
# a `bertopic.representation` model
representation_model = KeyBERTInspired()

# # Step 6 - (Optional) Fine-tune topic representations with 
# pos_patterns = [
#             [{'POS': 'ADJ'}, {'POS': 'NOUN'}],
#             [{'POS': 'NOUN'}], [{'POS': 'ADJ'}],
#             [{'POS': 'ADJ'}, {'POS': 'ADJ'}, {'POS': 'NOUN'}],
#             [{'POS': 'NOUN'}],
#             [{'POS': 'NOUN'},{'POS': 'NOUN'}]

# ]
# representation_model = PartOfSpeech("en_core_web_lg", pos_patterns=pos_patterns)

# All steps together
min_topic_model_processed = BERTopic(
  min_topic_size=100,
  language="english", 
  top_n_words=20, 
  calculate_probabilities=True,
  n_gram_range=(1, 3),
  verbose=True,
  embedding_model=embedding_model,          # Step 1 - Extract embeddings
  umap_model=umap_model,                    # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,              # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,        # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                # Step 5 - Extract topic words
  representation_model=representation_model # Step 6 - (Optional) Fine-tune topic represenations
)

min_topics_processed, min_probs_processed = min_topic_model_processed.fit_transform(train_df['preprocessed_abstract'],y=train_df['label_num'])
# Out:
# Batches:   0%|          | 0/656 [00:00<?, ?it/s]
# 2023-04-06 00:10:30,283 - BERTopic - Transformed documents to Embeddings
# 2023-04-06 00:10:40,453 - BERTopic - Reduced dimensionality
# 2023-04-06 00:10:55,747 - BERTopic - Clustered reduced embeddings

# %%
freq = min_topic_model_processed.get_topic_info()
freq
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Topic</th>
#       <th>Count</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1</td>
#       <td>4351</td>
#       <td>-1_learning_models_algorithms_networks</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>5485</td>
#       <td>0_magnetic_spin_quantum_phase</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>4404</td>
#       <td>1_this paper we_theorem_this paper_theory</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>380</td>
#       <td>2_semantics_logics_decidable_automata</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>280</td>
#       <td>3_deep learning_deep neural_deep neural networ...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>106</td>
#       <td>18</td>
#       <td>106_knowledge graph embeddings_knowledge graph...</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>107</td>
#       <td>17</td>
#       <td>107_quantum channel_ideal quantum channel_quan...</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>108</td>
#       <td>17</td>
#       <td>108_aerial vehicles_tracking control_uav_attit...</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>109</td>
#       <td>16</td>
#       <td>109_signaling networks_protein complexes_signa...</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>110</td>
#       <td>15</td>
#       <td>110_restricted boltzmann machine_restricted bo...</td>
#     </tr>
#   </tbody>
# </table>
# <p>112 rows × 3 columns</p>
# </div>

# %%
freq.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Topic</th>
#       <th>Count</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1</td>
#       <td>4351</td>
#       <td>-1_learning_models_algorithms_networks</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>5485</td>
#       <td>0_magnetic_spin_quantum_phase</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>4404</td>
#       <td>1_this paper we_theorem_this paper_theory</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>380</td>
#       <td>2_semantics_logics_decidable_automata</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>280</td>
#       <td>3_deep learning_deep neural_deep neural networ...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>243</td>
#       <td>4_slam_pose_vision_camera</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5</td>
#       <td>217</td>
#       <td>5_graphs_of graph_graph is_complexity</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>6</td>
#       <td>172</td>
#       <td>6_arbitrage_markets_market_liquidity</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>7</td>
#       <td>167</td>
#       <td>7_mimo_transmit_antennas_wireless</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>8</td>
#       <td>156</td>
#       <td>8_speech recognition_automatic speech_automati...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>9</td>
#       <td>148</td>
#       <td>9_meta analysis_statistical_causal_the causal</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>10</td>
#       <td>145</td>
#       <td>10_brain networks_neural_of neural_neuron</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>11</td>
#       <td>144</td>
#       <td>11_classifiers_classifier_classification_multi...</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>12</td>
#       <td>142</td>
#       <td>12_word embeddings_sentiment analysis_natural ...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>13</td>
#       <td>124</td>
#       <td>13_stochastic gradient descent_stochastic opti...</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>14</td>
#       <td>123</td>
#       <td>14_microgrid_power flow_power systems_renewabl...</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>15</td>
#       <td>111</td>
#       <td>15_tweets_social media_twitter_on social media</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>16</td>
#       <td>103</td>
#       <td>16_linear codes_ldpc codes_decoding algorithm_...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>17</td>
#       <td>97</td>
#       <td>17_gpus_gpu_cores_memory</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>18</td>
#       <td>95</td>
#       <td>18_in social networks_social network_of networ...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
min_topic_model_processed.get_topic(0)
# Out:
# Out[144]: [('magnetic', 0.30588767),
#  ('spin', 0.22316842),
#  ('quantum', 0.19854933),
#  ('phase', 0.18576126),
#  ('electron', 0.1781575),
#  ('galaxies', 0.17560966),
#  ('dynamics', 0.1731713),
#  ('star', 0.14322568),
#  ('energy', 0.12963197),
#  ('transition', 0.118588366)]

# %%
min_topic_model_processed.get_topic(1)
# Out:
# Out[145]: [('this paper we', 0.29324612),
#  ('theorem', 0.29166406),
#  ('this paper', 0.23478912),
#  ('theory', 0.22877887),
#  ('in this paper', 0.20950463),
#  ('conditions', 0.19376747),
#  ('any', 0.18236612),
#  ('of', 0.1759616),
#  ('general', 0.16993664),
#  ('on', 0.16932659)]

# %%
min_topic_model_processed.get_topic(2)
# Out:
# Out[146]: [('semantics', 0.45382175),
#  ('logics', 0.4317517),
#  ('decidable', 0.4185804),
#  ('automata', 0.40899402),
#  ('abstract', 0.3822445),
#  ('logic', 0.35762882),
#  ('automaton', 0.33087435),
#  ('complexity', 0.30450425),
#  ('concurrent', 0.29795772),
#  ('formal', 0.28988218)]

# %%
min_topic_model_processed.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="0e2e1a00-4d1d-42e7-80f7-858cf7c6ae91" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e2e1a00-4d1d-42e7-80f7-858cf7c6ae91")) {                    Plotly.newPlot(                        "0e2e1a00-4d1d-42e7-80f7-858cf7c6ae91",                        [{"customdata":[[0,"magnetic | spin | quantum | phase | electron",5485],[1,"this paper we | theorem | this paper | theory | in this paper",4404],[2,"semantics | logics | decidable | automata | abstract",380],[3,"deep learning | deep neural | deep neural networks | imagenet | convolutional neural networks",280],[4,"slam | pose | vision | camera | cameras",243],[5,"graphs | of graph | graph is | complexity | algorithms",217],[6,"arbitrage | markets | market | liquidity | stochastic",172],[7,"mimo | transmit | antennas | wireless | antenna",167],[8,"speech recognition | automatic speech | automatic speech recognition | speech enhancement | speaker verification",156],[9,"meta analysis | statistical | causal | the causal | models",148],[10,"brain networks | neural | of neural | neuron | neuronal",145],[11,"classifiers | classifier | classification | multi label | svm",144],[12,"word embeddings | sentiment analysis | natural language processing | corpus | nlp",142],[13,"stochastic gradient descent | stochastic optimization | stochastic gradient | gradient descent | sgd",124],[14,"microgrid | power flow | power systems | renewable energy | power system",123],[15,"tweets | social media | twitter | on social media | on twitter",111],[16,"linear codes | ldpc codes | decoding algorithm | decoding | decoder",103],[17,"gpus | gpu | cores | memory | processor",97],[18,"in social networks | social network | of networks | social networks | network science",95],[19,"networks gans | gan training | generative adversarial networks | generative adversarial | generative adversarial network",94],[20,"graph neural | network embedding | network representation | graph convolutional | node classification",93],[21,"software development | of software | software | agile | the software",88],[22,"bandit problem | contextual bandit | contextual bandits | multi armed bandit | bandit",83],[23,"medical images | medical image | deep learning | cnn | image segmentation",82],[24,"differential privacy | privacy preserving | data privacy | of differential privacy | privacy loss",81],[25,"finite element method | numerical | discretization | mesh | element method",80],[26,"deep reinforcement learning | reinforcement learning rl | deep reinforcement | reinforcement learning | in reinforcement learning",79],[27,"optimal control | control systems | lqg control | lyapunov | constraints",77],[28,"citations | bibliometric | of citation | citation | cited",75],[29,"of neural networks | deep neural networks | deep neural | neural networks | gradient descent",75],[30,"of community detection | community detection | community detection methods | community structure | communities",75],[31,"to adversarial examples | adversarial training | adversarial samples | adversarial examples | vulnerable to adversarial",74],[32,"gaussians | clustering | gaussian | sample complexity | mixtures of",73],[33,"nash equilibrium | nash equilibria | equilibrium | allocation | optimal",71],[34,"collaborative filtering | recommender systems | recommender | the recommendation | recommendation",65],[35,"biased dispersal | of species | dispersal | ecological | ecosystems",64],[36,"robotic grasping | grasping | grasps | grasp | robotic",63],[37,"compressed sensing | compressive sensing | sparse signals | signal recovery | compressive",60],[38,"matrix completion | nonnegative matrix factorization | matrix factorization | low rank | subspace clustering",59],[39,"motion pl ...

# %%
min_topic_model_processed.visualize_hierarchy(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="c8d6dce6-0efb-4b98-bd0e-af38f1fc0fcd" class="plotly-graph-div" style="height:650px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8d6dce6-0efb-4b98-bd0e-af38f1fc0fcd")) {                    Plotly.newPlot(                        "c8d6dce6-0efb-4b98-bd0e-af38f1fc0fcd",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.46664138718725057,0.46664138718725057,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7635482006694859,0.7635482006694859,0.46664138718725057],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7873948854254678,0.7873948854254678,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6803471043941864,0.6803471043941864,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.7873948854254678,0.8782994632298151,0.8782994632298151,0.6803471043941864],"xaxis":"x","y":[-40.0,-40.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8782994632298151,0.9248719953280032,0.9248719953280032,0.0],"xaxis":"x","y":[-50.0,-50.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.7635482006694859,1.1924136363967326,1.1924136363967326,0.9248719953280032],"xaxis":"x","y":[-12.5,-12.5,-62.5,-62.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8185554103216005,0.8185554103216005,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9589083491164713,0.9589083491164713,0.8185554103216005],"xaxis":"x","y":[-95.0,-95.0,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9694473573845155,0.9694473573845155,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9589083491164713,1.0176389132138066,1.0176389132138066,0.9694473573845155],"xaxis":"x","y":[-102.5,-102.5,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1804138931687689,1.1804138931687689,1.0176389132138066],"xaxis":"x","y":[-85.0,-85.0,-116.25,-116.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9164981078417999,0.9164981078417999,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9517521554796451,0.9517521554796451,0.9164981078417999],"xaxis":"x","y":[-145.0,-145.0,-160.0,-160.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.1804138931687689,1.2337383709096512,1.2337383709096512,0.9517521554796451],"xaxis":"x","y":[-100.625,-100.625,-152.5,-152.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.830696245571778,0.830696245571778,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.890650561647343 ...

# %%
min_topic_model_processed.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="c357997f-2844-435e-9663-09a64d963273" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c357997f-2844-435e-9663-09a64d963273")) {                    Plotly.newPlot(                        "c357997f-2844-435e-9663-09a64d963273",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.1781574934720993,0.1857612580060959,0.1985493302345276,0.22316841781139374,0.3058876693248749],"y":["electron  ","phase  ","quantum  ","spin  ","magnetic  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.209504634141922,0.2287788689136505,0.23478911817073822,0.2916640639305115,0.2932461202144623],"y":["in this paper  ","theory  ","this paper  ","theorem  ","this paper we  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.3822444975376129,0.40899401903152466,0.41858041286468506,0.43175169825553894,0.45382174849510193],"y":["abstract  ","automata  ","decidable  ","logics  ","semantics  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.47874152660369873,0.479219913482666,0.5606564879417419,0.5610170364379883,0.5664522647857666],"y":["convolutional neural networks  ","imagenet  ","deep neural networks  ","deep neural  ","deep learning  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.3484193682670593,0.3728719651699066,0.375670462846756,0.3848555386066437,0.4698053002357483],"y":["cameras  ","camera  ","vision  ","pose  ","slam  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.4225681722164154,0.42368265986442566,0.4500299394130707,0.4693972170352936,0.5024272799491882],"y":["algorithms  ","complexity  ","graph is  ","of graph  ","graphs  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.396688848733902,0.42431700229644775,0.4243937134742737,0.4528822600841522,0.46218082308769226],"y":["stochastic  ","liquidity  ","market  ","markets  ","arbitrage  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.3159506320953369,0.3385516107082367,0.3496206998825073,0.36758244037628174,0.37313607335090637],"y":["antenna  ","wireless  ","antennas  ","transmit  ","mimo  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.43101978302001953,0.503444492816925,0.5516254305839539,0.5605625510215759,0.5942176580429077],"y":["speaker verification  ","speech enhancement  ","automatic speech recognition  ","automatic speech  ","speech recognition  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.27478182315826416,0.2920636534690857,0.3100469708442688,0.31097403168678284,0.37526562809944153],"y":["models  ","the causal  ","causal  ","statistical  ","meta analysis  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}], ...

# %%
min_topic_model_processed.visualize_heatmap(n_clusters=20, width=1000, height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="5f6d7896-c084-43ff-86a3-c5c938e2d412" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f6d7896-c084-43ff-86a3-c5c938e2d412")) {                    Plotly.newPlot(                        "5f6d7896-c084-43ff-86a3-c5c938e2d412",                        [{"coloraxis":"coloraxis","name":"0","x":["0_magnetic_spin_quantum","1_this paper we_theorem_thi...","4_slam_pose_vision","9_meta analysis_statistical...","32_gaussians_clustering_gau...","56_forecasting_deep learnin...","63_forecasting_forecast_for...","68_mortality_to estimate_mo...","2_semantics_logics_decidable","21_software development_of ...","95_of computational thinkin...","101_ai researchers_explaina...","3_deep learning_deep neural...","11_classifiers_classifier_c...","23_medical images_medical i...","29_of neural networks_deep ...","46_classifiers_optimal clas...","65_deep learning_deep neura...","104_deep learning_deep neur...","5_graphs_of graph_graph is","18_in social networks_socia...","20_graph neural_network emb...","30_of community detection_c...","78_spectral clustering_grap...","83_evolving networks_number...","6_arbitrage_markets_market","22_bandit problem_contextua...","33_nash equilibrium_nash eq...","58_bandit problem_bandit_ba...","73_computer chess_world com...","85_evolution of cooperation...","7_mimo_transmit_antennas","14_microgrid_power flow_pow...","15_tweets_social media_twit...","17_gpus_gpu_cores","54_server queues_group serv...","61_human mobility_urban bou...","8_speech recognition_automa...","12_word embeddings_sentimen...","55_face images_face image_f...","66_visual question answerin...","70_clinical data_icu mortal...","77_human action recognition...","81_zero shot learning_zero ...","84_sleep stage classificati...","10_brain networks_neural_of...","75_spiking neural networks_...","13_stochastic gradient desc...","42_variational inference_va...","60_memory lstm_term memory ...","80_variational autoencoders...","99_stochastic gradient desc...","110_restricted boltzmann ma...","16_linear codes_ldpc codes_...","34_collaborative filtering_...","52_machine translation nmt_...","53_approximate string match...","64_information retrieval_se...","106_knowledge graph embeddi...","19_networks gans_gan traini...","31_to adversarial examples_...","48_to adversarial examples_...","86_training gans_networks g...","24_differential privacy_pri...","45_monte carlo mcmc_sequent...","57_of attack detection_atta...","76_caching scheme_coded cac...","87_economic growth_economy_...","90_quantile regression_quan...","92_traffic flow forecasting...","97_knapsack_dual bin packin...","100_the blockchain_the bloc...","25_finite element method_nu...","37_compressed sensing_compr...","38_matrix completion_nonneg...","49_matrix completion_low ra...","59_ct images_deep learning_...","62_mixture models_mixture m...","72_image denoising_denoisin...","88_gaussian processes_gauss...","102_bootstrap lasso ols_boo...","26_deep reinforcement learn...","27_optimal control_control ...","43_deep reinforcement_deep ...","71_policy learning_deep rei...","93_boolean network_boolean ...","94_multi agent systems_opti...","28_citations_bibliometric_o...","35_biased dispersal_of spec...","50_intracellular_multicellu...","69_folding simulation_molec...","79_phylogenetic tree_gene t...","98_epidemic model_epidemics...","109_signaling networks_prot...","36_robotic grasping_graspin...","39_motion planning_path pla...","40_humanoid robots_locomoti...","67_human driven vehicles_au...","89_human robot collaboratio...","108_aerial vehicles_trackin...","41_adic complexity of_adic ...","105_reduced proof graphs_co...","44_quantum algorithms_quant...","51_low rank tensor_rank ten...","103_solving eigenvalue p ...

# %%
topic_info=min_topic_model_processed.get_topic_info()
topic_info['mapping']=tuple(zip(topic_info.Topic, topic_info.Name))
topic_info
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Topic</th>
#       <th>Count</th>
#       <th>Name</th>
#       <th>mapping</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1</td>
#       <td>4351</td>
#       <td>-1_learning_models_algorithms_networks</td>
#       <td>(-1, -1_learning_models_algorithms_networks)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>5485</td>
#       <td>0_magnetic_spin_quantum_phase</td>
#       <td>(0, 0_magnetic_spin_quantum_phase)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>4404</td>
#       <td>1_this paper we_theorem_this paper_theory</td>
#       <td>(1, 1_this paper we_theorem_this paper_theory)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>380</td>
#       <td>2_semantics_logics_decidable_automata</td>
#       <td>(2, 2_semantics_logics_decidable_automata)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>280</td>
#       <td>3_deep learning_deep neural_deep neural networ...</td>
#       <td>(3, 3_deep learning_deep neural_deep neural ne...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>106</td>
#       <td>18</td>
#       <td>106_knowledge graph embeddings_knowledge graph...</td>
#       <td>(106, 106_knowledge graph embeddings_knowledge...</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>107</td>
#       <td>17</td>
#       <td>107_quantum channel_ideal quantum channel_quan...</td>
#       <td>(107, 107_quantum channel_ideal quantum channe...</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>108</td>
#       <td>17</td>
#       <td>108_aerial vehicles_tracking control_uav_attit...</td>
#       <td>(108, 108_aerial vehicles_tracking control_uav...</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>109</td>
#       <td>16</td>
#       <td>109_signaling networks_protein complexes_signa...</td>
#       <td>(109, 109_signaling networks_protein complexes...</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>110</td>
#       <td>15</td>
#       <td>110_restricted boltzmann machine_restricted bo...</td>
#       <td>(110, 110_restricted boltzmann machine_restric...</td>
#     </tr>
#   </tbody>
# </table>
# <p>112 rows × 4 columns</p>
# </div>

# %%
train_df['prediction']=np.array(min_topics_processed)
new_dict={}
for i in topic_info['mapping']:
    new_dict[i[0]]=i[1]
print(new_dict)
train_df['prediction_name']=train_df['prediction'].map(new_dict)
train_df.head()
# Out:
# {-1: '-1_learning_models_algorithms_networks', 0: '0_magnetic_spin_quantum_phase', 1: '1_this paper we_theorem_this paper_theory', 2: '2_semantics_logics_decidable_automata', 3: '3_deep learning_deep neural_deep neural networks_imagenet', 4: '4_slam_pose_vision_camera', 5: '5_graphs_of graph_graph is_complexity', 6: '6_arbitrage_markets_market_liquidity', 7: '7_mimo_transmit_antennas_wireless', 8: '8_speech recognition_automatic speech_automatic speech recognition_speech enhancement', 9: '9_meta analysis_statistical_causal_the causal', 10: '10_brain networks_neural_of neural_neuron', 11: '11_classifiers_classifier_classification_multi label', 12: '12_word embeddings_sentiment analysis_natural language processing_corpus', 13: '13_stochastic gradient descent_stochastic optimization_stochastic gradient_gradient descent', 14: '14_microgrid_power flow_power systems_renewable energy', 15: '15_tweets_social media_twitter_on social media', 16: '16_linear codes_ldpc codes_decoding algorithm_decoding', 17: '17_gpus_gpu_cores_memory', 18: '18_in social networks_social network_of networks_social networks', 19: '19_networks gans_gan training_generative adversarial networks_generative adversarial', 20: '20_graph neural_network embedding_network representation_graph convolutional', 21: '21_software development_of software_software_agile', 22: '22_bandit problem_contextual bandit_contextual bandits_multi armed bandit', 23: '23_medical images_medical image_deep learning_cnn', 24: '24_differential privacy_privacy preserving_data privacy_of differential privacy', 25: '25_finite element method_numerical_discretization_mesh', 26: '26_deep reinforcement learning_reinforcement learning rl_deep reinforcement_reinforcement learning', 27: '27_optimal control_control systems_lqg control_lyapunov', 28: '28_citations_bibliometric_of citation_citation', 29: '29_of neural networks_deep neural networks_deep neural_neural networks', 30: '30_of community detection_community detection_community detection methods_community structure', 31: '31_to adversarial examples_adversarial training_adversarial samples_adversarial examples', 32: '32_gaussians_clustering_gaussian_sample complexity', 33: '33_nash equilibrium_nash equilibria_equilibrium_allocation', 34: '34_collaborative filtering_recommender systems_recommender_the recommendation', 35: '35_biased dispersal_of species_dispersal_ecological', 36: '36_robotic grasping_grasping_grasps_grasp', 37: '37_compressed sensing_compressive sensing_sparse signals_signal recovery', 38: '38_matrix completion_nonnegative matrix factorization_matrix factorization_low rank', 39: '39_motion planning_path planning_robotics_planning problem', 40: '40_humanoid robots_locomotion_kinematic_kinematics', 41: '41_adic complexity of_adic complexity_linear complexity_finite field', 42: '42_variational inference_variational autoencoders_variational autoencoder_generative models', 43: '43_deep reinforcement_deep reinforcement learning_learning agents_reinforcement learning', 44: '44_quantum algorithms_quantum computing_quantum computation_quantum computers', 45: '45_monte carlo mcmc_sequential monte carlo_markov chain monte_chain monte carlo', 46: '46_classifiers_optimal classifier_classifier_classification', 47: '47_automatic music_music information retrieval_music generation_polyphonic music', 48: '48_to adversarial examples_of adversarial examples_against adversarial_adversarial examples in', 49: '49_matrix completion_low rank matrix_subspace clustering_component analysis', 50: '50_intracellular_multicellular_extracellular_cells', 51: '51_low rank tensor_rank tensor completion_rank tensor_tensor completion', 52: '52_machine translation nmt_neural machine translation_machine translation_machine translation system', 53: '53_approximate string matching_string matching_approximate string_pattern matching', 54: '54_server queues_group server queues_queue_sdn', 55: '55_face images_face image_face recognition_face detection', 56: '56_forecasting_ ...
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>TITLE</th>
#       <th>ABSTRACT</th>
#       <th>preprocessed_abstract</th>
#       <th>label</th>
#       <th>label_num</th>
#       <th>prediction</th>
#       <th>prediction_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Reconstructing Subject-Specific Effect Maps</td>
#       <td>Predictive models allow subject-specific inf...</td>
#       <td>predictive models allow subject specific infe...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#       <td>-1</td>
#       <td>-1_learning_models_algorithms_networks</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Rotation Invariance Neural Network</td>
#       <td>Rotation invariance and translation invarian...</td>
#       <td>rotation invariance and translation invarianc...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#       <td>3</td>
#       <td>3_deep learning_deep neural_deep neural networ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Spherical polyharmonics and Poisson kernels fo...</td>
#       <td>We introduce and develop the notion of spher...</td>
#       <td>we introduce and develop the notion of spheri...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1_this paper we_theorem_this paper_theory</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>A finite element approximation for the stochas...</td>
#       <td>The stochastic Landau--Lifshitz--Gilbert (LL...</td>
#       <td>the stochastic landau lifshitz gilbert llg eq...</td>
#       <td>Mathematics</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1_this paper we_theorem_this paper_theory</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Comparative study of Discrete Wavelet Transfor...</td>
#       <td>Fourier-transform infra-red (FTIR) spectra o...</td>
#       <td>fourier transform infra red ftir spectra of s...</td>
#       <td>Computer Science</td>
#       <td>0</td>
#       <td>-1</td>
#       <td>-1_learning_models_algorithms_networks</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_df['label'].value_counts()
# Out:
# Out[165]: Computer Science        8594
# Physics                 5521
# Mathematics             4436
# Statistics              1765
# Quantitative Biology     447
# Quantitative Finance     209
# Name: label, dtype: int64

# %%
a=train_df[train_df['label']=='Computer Science']['prediction_name'].value_counts() #total 8594
a[a>50]
# Out:
# Out[166]: -1_learning_models_algorithms_networks                                                                3414
# 2_semantics_logics_decidable_automata                                                                  378
# 3_deep learning_deep neural_deep neural networks_imagenet                                              277
# 4_slam_pose_vision_camera                                                                              240
# 5_graphs_of graph_graph is_complexity                                                                  212
# 7_mimo_transmit_antennas_wireless                                                                      166
# 8_speech recognition_automatic speech_automatic speech recognition_speech enhancement                  154
# 11_classifiers_classifier_classification_multi label                                                   142
# 12_word embeddings_sentiment analysis_natural language processing_corpus                               142
# 13_stochastic gradient descent_stochastic optimization_stochastic gradient_gradient descent            124
# 14_microgrid_power flow_power systems_renewable energy                                                 117
# 15_tweets_social media_twitter_on social media                                                         110
# 16_linear codes_ldpc codes_decoding algorithm_decoding                                                 102
# 17_gpus_gpu_cores_memory                                                                                97
# 19_networks gans_gan training_generative adversarial networks_generative adversarial                    94
# 18_in social networks_social network_of networks_social networks                                        93
# 20_graph neural_network embedding_network representation_graph convolutional                            92
# 21_software development_of software_software_agile                                                      88
# 22_bandit problem_contextual bandit_contextual bandits_multi armed bandit                               82
# 25_finite element method_numerical_discretization_mesh                                                  80
# 26_deep reinforcement learning_reinforcement learning rl_deep reinforcement_reinforcement learning      79
# 23_medical images_medical image_deep learning_cnn                                                       79
# 24_differential privacy_privacy preserving_data privacy_of differential privacy                         78
# 27_optimal control_control systems_lqg control_lyapunov                                                 77
# 30_of community detection_community detection_community detection methods_community structure           75
# 31_to adversarial examples_adversarial training_adversarial samples_adversarial examples                74
# 32_gaussians_clustering_gaussian_sample complexity                                                      72
# 28_citations_bibliometric_of citation_citation                                                          70
# 33_nash equilibrium_nash equilibria_equilibrium_allocation                                              69
# 34_collaborative filtering_recommender systems_recommender_the recommendation                           65
# 36_robotic grasping_grasping_grasps_grasp                                                               63
# 38_matrix completion_nonnegative matrix factorization_matrix factorization_low rank                     58
# 37_compressed sensing_compressive sensing_sparse signals_signal recovery                                56
# 39_motion planning_path planning_robotics_planning problem                                              55
# 42_variational inference_variational autoencoders_variational autoencoder_generative models             54
# 40_humanoid robots_locomotion_kinematic_kinematics                                                      54
# 41_adic complexity of_adic complexity_linear complexity_finite field                                    52
# 44_quantum algorithms_quantum computing_quantum computation_quantum computers                           51
# Name: prediction_name, dtype: int64

# %%
b=train_df[train_df['label']=='Physics']['prediction_name'].value_counts() #total 5521
b[b>50]
# Out:
# Out[159]: 0_magnetic_spin_quantum_phase    5458
# Name: prediction_name, dtype: int64

# %%
c=train_df[train_df['label']=='Quantitative Biology']['prediction_name'].value_counts() #total 447
c[c>10]
# Out:
# Out[158]: 10_brain networks_neural_of neural_neuron                                                  141
# -1_learning_models_algorithms_networks                                                      87
# 35_biased dispersal_of species_dispersal_ecological                                         64
# 50_intracellular_multicellular_extracellular_cells                                          49
# 69_folding simulation_molecular_molecule_the molecule                                       33
# 79_phylogenetic tree_gene trees_phylogenetic_phylogenetic networks                          26
# 98_epidemic model_epidemics_epidemic_of infection                                           22
# 109_signaling networks_protein complexes_signaling networks with_complexes and pathways     16
# Name: prediction_name, dtype: int64

# %%
d=train_df[train_df['label']=='Quantitative Finance']['prediction_name'].value_counts() #total 209
d[d>10]
# Out:
# Out[160]: 6_arbitrage_markets_market_liquidity                               165
# 87_economic growth_economy_economic_international tax avoidance     24
# -1_learning_models_algorithms_networks                              11
# Name: prediction_name, dtype: int64

# %%
e=train_df[train_df['label']=='Statistics']['prediction_name'].value_counts() #total 1765
e[e>10]
# Out:
# Out[161]: -1_learning_models_algorithms_networks                                                                       780
# 9_meta analysis_statistical_causal_the causal                                                                146
# 29_of neural networks_deep neural networks_deep neural_neural networks                                        75
# 43_deep reinforcement_deep reinforcement learning_learning agents_reinforcement learning                      54
# 48_to adversarial examples_of adversarial examples_against adversarial_adversarial examples in                50
# 45_monte carlo mcmc_sequential monte carlo_markov chain monte_chain monte carlo                               50
# 46_classifiers_optimal classifier_classifier_classification                                                   50
# 49_matrix completion_low rank matrix_subspace clustering_component analysis                                   49
# 56_forecasting_deep learning_forecasts_predicting                                                             43
# 58_bandit problem_bandit_bandits_bandits with                                                                 41
# 59_ct images_deep learning_computed tomography_convolutional neural                                           41
# 62_mixture models_mixture model_gaussian mixture_mixture components                                           38
# 63_forecasting_forecast_forecasts_autoregressive                                                              36
# 68_mortality_to estimate_models_gdp                                                                           34
# 80_variational autoencoders_variational autoencoder_variational autoencoder vae_variational auto encoders     29
# 83_evolving networks_number of communities_random graph_time evolving networks                                27
# 84_sleep stage classification_eeg signals_eeg_sleep stages                                                    27
# 86_training gans_networks gan_gan training_adversarial network gan                                            26
# 90_quantile regression_quantile functions_the estimators_the quantile                                         23
# 88_gaussian processes_gaussian process_nearest neighbor gaussian_parent gaussian                              23
# 96_fairness aware classification_fairness metrics_fairness aware_kinds of fairness                            22
# 99_stochastic gradient descent_stochastic gradients_unbiased stochastic gradients_stochastic gradient         21
# 102_bootstrap lasso ols_bootstrap lasso_sparse feature selection_lasso                                        19
# 104_deep learning_deep neural_bioinformatics_deep neural network                                              18
# Name: prediction_name, dtype: int64

# %%
f=train_df[train_df['label']=='Mathematics']['prediction_name'].value_counts() #toal 4436
f[f>10]
# Out:
# Out[164]: 1_this paper we_theorem_this paper_theory    4371
# -1_learning_models_algorithms_networks         29
# 0_magnetic_spin_quantum_phase                  12
# Name: prediction_name, dtype: int64
